# %%
using Flux, Flux.Data.MNIST
using Flux: @epochs, mse, onehotbatch
using Random
using Base.Iterators: partition
using BSON: @load, @save


imgs = MNIST.images(:train)
train_X = hcat(float.(vec.(imgs))...)
labels = MNIST.labels(:train)
train_Y = onehotbatch(labels,0:9)

batchsize = 64
train_dataset = ([(train_X[:,batch] ,train_Y[:,batch]) for batch in partition(1:size(train_Y)[2],batchsize)])

model = Chain(
  Dense(28^2, 32, relu),
  Dense(32, 32, relu),
  Dense(32, 10),
  softmax)

loss(x, y) = mse(model(x), y) 
opt = ADAM(params(model))

@epochs 100 Flux.train!(loss, train_dataset, opt)

# モデルの保存
pretrained = model |> cpu
weights = Tracker.data.(params(pretrained))
@save "pretrained.bson" pretrained
@save "weights.bson" weights
println("Finished to train")
# Out:
# ┌ Info: Epoch 1
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 2
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 3
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 4
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 5
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 6
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 7
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 8
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 9
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 10
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 11
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 12
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 13
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 14
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 15
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 16
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 17
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 18
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 19
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 20
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 21
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 22
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 23
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 24
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 25
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 26
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 27
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 28
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 29
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 30
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 31
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 32
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 33
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 34
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 35
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 36
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 37
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 38
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 39
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
# ┌ Info: Epoch 40
# └ @ Main /Users/noriakioshita/.julia/packages/Flux/oN61x/src/optimise/train.jl:93
